# %%
import os
import asyncio
from langchain_aws import BedrockEmbeddings
from langchain_community.vectorstores import Chroma
from langchain_community.document_loaders import PyPDFLoader

# %%
# Configuration des embeddings Bedrock
embeddings = BedrockEmbeddings(
    credentials_profile_name="default",
    region_name="us-west-2",
    model_id='amazon.titan-embed-text-v2:0',
)

pdfs_directory = './documents'

# Fonction pour charger des documents à partir de fichiers PDF
def load_documents_from_pdfs(file_path):
    loader = PyPDFLoader(file_path)
    return  loader.load() # Added return statement

# Fonction d'embedding des documents
async def embed_documents(documents):
    # Embedding de tous les documents
    document_embeddings = await embeddings.aembed_documents([doc.page_content for doc in documents])
    return document_embeddings

# %%
print("Chargement des documents depuis les fichiers PDF...")
documents = []

# Charger tous les fichiers PDF dans le répertoire spécifié
for filename in os.listdir(pdfs_directory):
    if filename.endswith('.pdf'):
        file_path = os.path.join(pdfs_directory, filename)
        docs = load_documents_from_pdfs(file_path)  # Call to load documents
# Out:
# Chargement des documents depuis les fichiers PDF...

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

text_splitter = RecursiveCharacterTextSplitter(
    # Set a really small chunk size, just to show.
    chunk_size=100,
    chunk_overlap=20,
    length_function=len,
    is_separator_regex=False,
)


docs = text_splitter.split_documents(docs)
docs
# Out:
# [Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 0}, page_content='Recommended Practices for  \nSafety  and Health  \nProgramsWorker Participation'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 0}, page_content='Find and Fix HazardsManagement Leadership\nOccupational Safety  \nand Health Administration'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 0}, page_content='osha.gov/safetymanagement\n      OSHA 3885 October 2016'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 1}, page_content='DISCLAIMER\nThese practices for safety and health programs are'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 1}, page_content='recommendations only.  Employers are not required to'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 1}, page_content='have a safety and health program that complies with'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 1}, page_content='them and will not be cited for failing to have a safety'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 1}, page_content='and health program that complies with this document.These recommended practices apply to employers,'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 1}, page_content='apply to employers,'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 1}, page_content='except in the construction industry, for whom there'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 1}, page_content='are separate Recommended Practices for Safety and \nHealth Programs for the Construction Industry.'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 2}, page_content='FOREWORDFOREWORD\nEstablishing a safety and health program in your'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 2}, page_content='workplace is one of the most effective ways \nof protecting your most valuable asset: your'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 2}, page_content='workers. Losing workers to injury or illness, even'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 2}, page_content='for a short time, can cause significant disruption'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 2}, page_content='and cost—to you as well as the workers and their \nfamilies. It can also damage workplace morale,'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 2}, page_content='productivity, turnover, and reputation.\nSafety and health programs foster a proactive'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 2}, page_content='approach to “finding and fixing” workplace \nhazards before they can cause injury or illness.'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 2}, page_content='Rather than reacting to an incident, management \nand workers collaborate to identify and solve'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 2}, page_content='issues before they occur. This collaboration builds'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 2}, page_content='trust, enhances communication, and often leads \nto other business improvements. Employers who'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 2}, page_content='have implemented safety and health programs, \nincluding many who are in OSHA’s Voluntary'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 2}, page_content='Protection Programs (VPP) or the Safety and \nHealth Achievement Recognition Program'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 2}, page_content='(SHARP) for small and medium-sized businesses, \nhave also found that managing for safety results'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 2}, page_content='in higher-quality product or output and higher \nprofits.\nThousands of responsible employers have'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 2}, page_content='used OSHA’s 1989 Safety and Health Program \nManagement Guidelines as a blueprint for setting'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 2}, page_content='up an effective safety and health program.1\nMuch has changed, however, since those'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 2}, page_content='guidelines were published: \n• The nature of work is evolving as the'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 2}, page_content='economy continues to shift from a \nmanufacturing to a service base, and from a'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 2}, page_content='fixed to an often mobile workforce.Resources and Tools to Support \nImplementation of These'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 2}, page_content='Recommended Practices\nOSHA has created a dedicated Web page'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 2}, page_content='to support the implementation of these \nrecommended practices at osha.gov/'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 2}, page_content='safetymanagement . The page includes the \nfollowing:\n• Additional resources. Articles and'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 2}, page_content='information sources related to each core \nelement of the recommended practices,'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 2}, page_content='plus other topics discussed in the \nrecommended practices. \n• Tools.  Downloadable templates,'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 2}, page_content='worksheets, and reference materials you \ncan use as you develop your own safety'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 2}, page_content='and health program. \nPlease visit the recommended practices \nWeb pa ge and explore the resources'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 2}, page_content='available. OSHA will update the Web page \nand add resources and tools as they become \navailable.'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 2}, page_content='available.\n• Automation of work activities means that \ntechnology, computers, and robotics are'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 2}, page_content='being integrated into our workplaces, often \nintroducing new and different hazards.'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 2}, page_content='• Greater diversity in the workplace means \nthat people from different backgrounds and'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 2}, page_content='cultures are working alongside each other, \noften speaking different languages.'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 2}, page_content='1 54 FR 3904–16, January 26, 1989.\ni osha.gov/safetymanagement'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 2}, page_content='RECOMMENDED PRACTICES FOR SAFETY AND HEALTH PROGRAMS'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 3}, page_content='FOREWORD• An aging workforce and the rise of sedentary \nwork and lifestyle means that some'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 3}, page_content='workers are at higher risk for work-related \nmusculoskeletal disorders.'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 3}, page_content='• There is greater recognition that workers \nin industries that some think of as safe'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 3}, page_content='(such as healthcare, lodging, retail, and \ntransportation) face significant hazards.'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 3}, page_content='• Increased temporary and contract \nemployment, and the rise of the “gig'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 3}, page_content='economy” mean that traditional relationships \nbetween workers and employers are shifting,'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 3}, page_content='and changes in safety programs and policies \nwill be required to ensure the safety of all'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 3}, page_content='workers at worksites characterized by these'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 3}, page_content='newer and more fluid relationships. These new recommended practices reflect these'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 3}, page_content='changes. They also reflect what we have learned \nfrom best-in-class programs and what makes'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 3}, page_content='them effective. In particular, these recommended \npractices place greater emphasis on involving'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 3}, page_content='workers, and include a more robust program \nevaluation element to help drive continuous'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 3}, page_content='improvement. The recommended practices \nalso stress the need for communication and'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 3}, page_content='coordination on worksites involving more than \none employer.'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 3}, page_content='one employer.\nIn addition, the new recommended practices'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 3}, page_content='build on successful approaches and practices \nthat have evolved under OSHA programs such'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 3}, page_content='VPP and SHARP. They also align with national \nand international consensus standards.2'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 3}, page_content='2 A comparison of these recommended practices, the 1989 guidelines, OSHA voluntary programs, and'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 3}, page_content='programs, and other consensus standards is'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 3}, page_content='available on the Recommended Practices for Safety and Health Programs website .\nii'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 3}, page_content='ii\nRECOMMENDED PRACTICES FOR SAFETY AND HEALTH PROGRAMS osha.gov/safetymanagement'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 4}, page_content='INTRODUCTION'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 4}, page_content='...................................................................................................'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 4}, page_content='....................................................................'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 4}, page_content='2'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 4}, page_content='MANAGEMENT LEADERSHIP'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 4}, page_content='...................................................................................................'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 4}, page_content='...........................................'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 4}, page_content='9'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 4}, page_content='WORKER PARTICIPATION'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 4}, page_content='...................................................................................................'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 4}, page_content='.................................................'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 4}, page_content='11'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 4}, page_content='HAZARD IDENTIFICATION AND ASSESSMENT'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 4}, page_content='ASSESSMENT ........................................................................................'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 4}, page_content='15'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 4}, page_content='HAZARD PREVENTION AND CONTROL'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 4}, page_content='...................................................................................................'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 4}, page_content='.....................'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 4}, page_content='20'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 4}, page_content='EDUCATION AND TRAINING'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 4}, page_content='...................................................................................................'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 4}, page_content='..........................................'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 4}, page_content='24'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 4}, page_content='PROGRAM EVALUATION AND IMPROVEMENT'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 4}, page_content='....................................................................................... 27'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 4}, page_content='COMMUNICATION AND COORDINATION FOR HOST EMPLOYERS, CONTRACTORS,'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 4}, page_content='AND STAFFING AGENCIES'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 4}, page_content='...................................................................................................'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 4}, page_content='..............................................'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 4}, page_content='30'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 4}, page_content='LIST OF ABBREVIATIONS'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 4}, page_content='...................................................................................................'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 4}, page_content='...............................................'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 4}, page_content='34'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 4}, page_content='GLOSSARY OF TERMS'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 4}, page_content='...................................................................................................'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 4}, page_content='.....................................................'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 4}, page_content='34CONTENTS'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 4}, page_content='1 osha.gov/safetymanagement\nRECOMMENDED PRACTICES FOR SAFETY AND HEALTH PROGRAMS'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 5}, page_content='INTRODUCTION\nTHESE RECOMMENDED PRACTICES  provide \nresponsible employers, workers, and worker'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 5}, page_content='representatives3 with a sound, flexible \nframework for addressing safety and health'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 5}, page_content='issues in diverse workplaces. They may be \nused in any workplace, but will be particularly'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 5}, page_content='helpful in small and medium-sized workplaces. \nThey can be applied equally well in traditional,'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 5}, page_content='fixed manufacturing workplaces and in the service sector, healthcare, retail, and even'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 5}, page_content='mobile or office-based work environments. \nThey also include information specifically aimed'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 5}, page_content='at temporary worker and multiemployer work \nsituations. Separate recommended practices are'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 5}, page_content='available for the construction industry.'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 5}, page_content='3 Worker participation is vital to the success of the program. In several places in this document,'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 5}, page_content='in this document, OSHA refers not just to workers but also'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 5}, page_content='to their representatives, such as labor unions or religious or community groups.'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 6}, page_content='Source: Ohio Bureau of Workers’ Compensation (2011), Ohio 21(d) SHARP Program Performance'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 6}, page_content='Program Performance Assessment.'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 6}, page_content='INTRODUCTIONThe recommended practices emphasize a \nproactive approach to managing workplace'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 6}, page_content='safety and health. Traditional approaches are'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 6}, page_content='often reactive—that is, actions are taken only after  a worker is injured or becomes sick, a'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 6}, page_content='new standard or regulation is published, or an \noutside inspection finds a problem that must'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 6}, page_content='be corrected. Finding and fixing hazards before'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 6}, page_content='they cause injury or illness is a far more effective approach. Doing so avoids the direct and'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 6}, page_content='the direct and indirect'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 6}, page_content='costs of worker injuries and illnesses, and \npromotes a positive work environment.'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 6}, page_content='The concept of continuous improvement is \ncentral to the recommended practices. As with'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 6}, page_content='any journey, the first step is often the most'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 6}, page_content='challenging. The idea is to begin with a basic program and grow from there. By initially focusing'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 6}, page_content='initially focusing on achieving modest goals, monitoring'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 6}, page_content='performance, and evaluating outcomes, you can'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 6}, page_content='help your workplace progress, over time, along the path to higher levels of safety and health. THE'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 6}, page_content='and health. THE BENEFITS OF IMPLEMENTING'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 6}, page_content='THESE RECOMMENDED PRACTICES\nResponsible employers know that the main goal'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 6}, page_content='of a safety and health program is to prevent \nworkplace injuries, illnesses, and deaths, as well'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 6}, page_content='as the suffering and financial hardship these events can cause for workers, their families, and'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 6}, page_content='their families, and their employers.'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 6}, page_content='Employers may find that implementing these \nrecommended practices brings other benefits'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 6}, page_content='as well. The renewed or enhanced commitment to safety and health and the cooperative'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 6}, page_content='atmosphere between employers and workers \nhave been linked to:'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 6}, page_content='• Improvements in product, process, and service quality. \n• Better workplace morale.'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 6}, page_content='• Improved employee recruiting and retention.'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 6}, page_content='• A more favorable image and reputation (among customers, suppliers, and the \ncommunity).'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 6}, page_content='community). \n(per million'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 6}, page_content='dollars of payroll)A study of small employers in Ohio found that workers’ compensation claims fell'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 6}, page_content='claims fell dramatically after working'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 6}, page_content='with OSHA’s SHARP program to adopt programs similar to those described in these recommended'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 6}, page_content='these recommended practices.'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 6}, page_content='average\nnumber of claims cost per claimclaims\n52%+\nDECREASED DECREASED'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 6}, page_content='DECREASED DECREASED\n80%88%DECREASEDaverage lost time per claim\n87%DECREASED'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 6}, page_content='87%DECREASED\n3 osha.gov/safetymanagement\nRECOMMENDED PRACTICES FOR SAFETY AND HEALTH PROGRAMS'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 7}, page_content='HOW TO USE THE RECOMMENDED \nPRACTICES\nEach section of the recommended practices'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 7}, page_content='describes a core program element (see page \n7), followed by several action items. Each'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 7}, page_content='action item is an example of steps that employers'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 7}, page_content='and workers can take to establish, implement, maintain, and improve your safety and health'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 7}, page_content='program. You can use the self-evaluation tool \nfound on the recommended practices Web pa ge'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 7}, page_content='to track your progress and assess how fully you have implemented (or will implement) each action'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 7}, page_content='each action item.'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 7}, page_content='Seven interrelated elements'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 7}, page_content='The seven core elements are interrelated and are best viewed as part of an integrated system.'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 7}, page_content='Actions taken under one core element can (and'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 7}, page_content='likely will) affect actions needed under one or more other elements. For example, workers must be'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 7}, page_content='workers must be trained in reporting procedures and hazard'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 7}, page_content='identification techniques in order to be effective Source: Leigh, J.P.  (2011), Economic Burden of'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 7}, page_content='Economic Burden of Occupational Injury and Illness in the United States. Milbank Quarterly,'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 7}, page_content='Milbank Quarterly, 89:728-772.4'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 7}, page_content='4 T he 2.7 multiplier for indirect costs includes some social costs, such as workers’ compensation'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 7}, page_content='compensation costs not covered by insurance.'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 7}, page_content='INTRODUCTIONIMPLEMENTING\na safety & health program\ncan help employers avoid the  \nthat result'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 7}, page_content='that result\nfrom  \ndue to work stoppages andinvestigations,'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 7}, page_content='training and other costs associated with \n to material, machinery and property. \n andsuch as'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 7}, page_content='andsuch as  \nTIME\nLOST\n  REPLACING \nINJURED WORKERS\n  LOSS ORDAMAGE\n \n INDIRECT\nCOSTS'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 7}, page_content='INDIRECT\nCOSTS\nThese  have been estimated\nto be at least  2.7\n      times theINDIRECT\nCOSTS'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 7}, page_content='COSTS\nDIRECT\nCOSTSWORKPLACE\nINCIDENTS\n4'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 7}, page_content='INCIDENTS\n4\nRECOMMENDED PRACTICES FOR SAFETY AND HEALTH PROGRAMS osha.gov/safetymanagement'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 8}, page_content='INTRODUCTION10 EASY THINGS TO GET YOUR PROGRAM STARTED'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 8}, page_content='If these recommended practices appear challenging, here are some simple steps you can'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 8}, page_content='take to get started. Completing these steps will give you a solid base from which to take on'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 8}, page_content='some of the more structured actions presented in the recommended practices.'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 8}, page_content='1. SET S AFETY AND HEALTH AS A \nTOP PRIORITY'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 8}, page_content='TOP PRIORITY\nAlways set safety and health as the top priority. Tell'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 8}, page_content='your workers that making sure they finish the day and go home safely is the way you do business.'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 8}, page_content='you do business. Assure'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 8}, page_content='them that you will work with them to find and fix any'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 8}, page_content='hazards that could injure them or make them sick.\n2. LEAD B Y EXAMPLE'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 8}, page_content='Practice safe behaviors yourself and make safety part of your daily conversations with workers.'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 8}, page_content='3. IMPLEMENT A REPOR TING \nSYSTEM'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 8}, page_content='Develop and communicate a simple procedure for workers to report any injuries, illnesses, incidents'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 8}, page_content='incidents (including near misses/close calls), hazards, or safety'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 8}, page_content='and health concerns without fear of retaliation.'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 8}, page_content='Include an option for reporting hazards or concerns anonymously.\n4. PRO VIDE TRAINING'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 8}, page_content='Train workers on how to identify and control hazards using, for example, OSHA’s Hazard'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 8}, page_content='OSHA’s Hazard Identification Training Tool.'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 8}, page_content='5. C ONDUCT INSPECTIONS'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 8}, page_content='Inspect the workplace with workers and ask them to identify any activity, piece of equipment, or'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 8}, page_content='of equipment, or material that concerns them. Use checklists, such as those'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 8}, page_content='included in OSHA’s Small Business Handbook, to help \nidentify problems.6. C OLLECT HAZARD CONTROL'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 8}, page_content='IDEAS'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 8}, page_content='Ask workers for ideas on improvements and follow up on their suggestions. Provide them time during'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 8}, page_content='them time during work hours, if necessary, to research solutions.'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 8}, page_content='7. IMPLEMENT HAZARD C ONTROLS'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 8}, page_content='Assign workers the task of choosing, implementing, and evaluating the solutions they come up with.'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 8}, page_content='8. ADDRES S EMERGENCIES'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 8}, page_content='Identify foreseeable emergency scenarios and develop instructions on what to do in each case. Meet'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 8}, page_content='in each case. Meet to discuss these procedures and post them in a visible'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 8}, page_content='location in the workplace.\n9. SEEK INPUT ON W ORKPLACE \nCHANGES'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 8}, page_content='CHANGES\nBefore making significant changes to the workplace,'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 8}, page_content='work organization, equipment, or materials, consult with workers to identify potential safety or'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 8}, page_content='potential safety or health'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 8}, page_content='issues. \n10. MAKE IMPRO VEMENTS\nSet aside a regular time to discuss safety and health'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 8}, page_content='issues, with the goal of identifying ways to improve the program.\n5 osha.gov/safetymanagement'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 8}, page_content='RECOMMENDED PRACTICES FOR SAFETY AND HEALTH PROGRAMS'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 9}, page_content='participants. Thus, the “Education and Training” \ncore element supports the “Worker Participation”'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 9}, page_content='core element. Similarly, setting goals (as \ndescribed under “Management Leadership”) will'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 9}, page_content='be more effective if you routinely evaluate your \nprogress in meeting those goals (see “Program'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 9}, page_content='Evaluation and Improvement”). Progress in each \ncore element is important to achieve maximum'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 9}, page_content='benefit from the program.\nOne size does not fit all\nWhile the action items under each core element'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 9}, page_content='are specific, they are not prescriptive. The \nprocess described in these recommended'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 9}, page_content='practices can, and should, be tailored to the \nneeds of each workplace. Likewise, your safety'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 9}, page_content='and health program can and should evolve. \nExperimentation, evaluation, and program'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 9}, page_content='modification are all part of the process. You \nmay also experience setbacks from time to'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 9}, page_content='time. What is important is that you learn from \nsetbacks, remain committed to finding out what'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 9}, page_content='works best for you, and continue to try different \napproaches.'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 9}, page_content='approaches. \nInjuries and illnesses occur in all types of'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 9}, page_content='workplace settings, from manufacturing sites, to'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 9}, page_content='hospitals and healthcare facilities, to offices and'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 9}, page_content='service industries.5 Workers can even be injured \nor become ill outside physical facilities, such'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 9}, page_content='as when driving a vehicle as part of a sales or \nservice job. The preventive approaches described'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 9}, page_content='in these recommended practices work equally \nwell across all sectors of the economy; for all'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 9}, page_content='different kinds of hazards; in both mobile and \nfixed work environments; and for small, medium-'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 9}, page_content='sized, and large organizations. Small employers \nmay find that they can best accomplish the'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 9}, page_content='actions outlined in these recommended practices \nusing informal communications and procedures.'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 9}, page_content='Larger employers, who have more complex work \nprocesses and hazards, may require a more'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 9}, page_content='formal and detailed program. They may also wish to integrate their safety and health program with'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 9}, page_content='other programs that they are using to manage \nproduction, quality control, and environmental'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 9}, page_content='protection or sustainability.\nThe importance of worker \nparticipation'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 9}, page_content='participation\nThroughout these recommended practices, \nOSHA emphasizes the importance of worker'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 9}, page_content='participation in the safety and health program. \nFor a program to succeed, workers (and,'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 9}, page_content='if applicable, their representatives) must \nparticipate in developing and implementing'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 9}, page_content='every element of the safety and health program. \nThis emphasis on worker participation is'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 9}, page_content='consistent with the OSH Act, OSHA standards, \nand OSHA enforcement policies and procedures,'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 9}, page_content='which recognize the rights and roles of workers \nand their representatives in matters of workplace'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 9}, page_content='safety and health. Several action items described \nin these recommended practices rely on'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 9}, page_content='perspectives, expertise, and input that can come \nonly from workers and their representatives.'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 9}, page_content='When more than one employer is \ninvolved\nHost employers, contractors, staffing agencies,'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 9}, page_content='and their workers should pay particular attention \nto the “Communication and Coordination for'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 9}, page_content='Host Employers, Contractors, and Staffing \nAgencies” section. This section describes'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 9}, page_content='actions that host employers and contractors, \nsubcontractors, and temporary staffing agencies'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 9}, page_content='(and their workers) should take to ensure \nprotection of everyone on the worksite.'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 9}, page_content='For tools and resources to help you \nimplement these recommended practices,'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 9}, page_content='visit: osha.gov/safetymanagement'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 9}, page_content='5 Please note: OSHA has developed a separate document of Recommended Practices for Safety and'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 9}, page_content='for Safety and Health Programs for the'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 9}, page_content='Construction Industry .\nINTRODUCTION\n6'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 9}, page_content='INTRODUCTION\n6\nRECOMMENDED PRACTICES FOR SAFETY AND HEALTH PROGRAMS osha.gov/safetymanagement'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 10}, page_content='INTRODUCTIONCORE ELEMENTS OF THE SAFETY AND HEALTH PROGRAM \nRECOMMENDED PRACTICES\nMANAGEMENT'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 10}, page_content='LEADERSHIP•  T op management demonstrates its commitment to continuous improvement in safety and'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 10}, page_content='health, communicates that commitment to workers, and sets program expectations and'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 10}, page_content='responsibilities.'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 10}, page_content='•  Manager s at all levels make safety and health a core organizational value, establish safety and'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 10}, page_content='safety and'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 10}, page_content='health goals and objectives, provide adequate resources and support for the program, and set a good'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 10}, page_content='and set a good example.'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 10}, page_content='WORKER'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 10}, page_content='PARTICIPATION•  W orkers and their representatives are involved in all aspects of the'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 10}, page_content='all aspects of the program—including setting'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 10}, page_content='goals, identifying and reporting hazards, investigating incidents, and tracking progress.'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 10}, page_content='•  All w orkers, including contractors and temporary workers, understand their roles and'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 10}, page_content='responsibilities under the program and what they need to do to effectively carry them out.'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 10}, page_content='•  W orkers are encouraged and have means to communicate openly with management and to'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 10}, page_content='report safety and health concerns without fear of retaliation.'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 10}, page_content='•  An y potential barriers or obstacles to worker participation in the program (for example,'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 10}, page_content='language, lack of information, or disincentives) are removed or addressed.\nHAZARD'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 10}, page_content='HAZARD \nIDENTIFICATION &'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 10}, page_content='ASSESSMENT•  Pr ocedures are put in place to continually identify workplace hazards and evaluate'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 10}, page_content='and evaluate risks.'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 10}, page_content='•  S afety and health hazards from routine, nonroutine, and emergency situations are identified'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 10}, page_content='and assessed.'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 10}, page_content='•  An initial as sessment of existing hazards, exposures, and control measures is followed by'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 10}, page_content='periodic inspections and reassessments, to identify new hazards.'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 10}, page_content='•  An y incidents are investigated with the goal of identifying the root causes.'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 10}, page_content='•  Iden tified hazards are prioritized for control.\nHAZARD  \nPREVENTION &'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 10}, page_content='CONTROL•  Emplo yers and workers cooperate to identify and select methods for eliminating,'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 10}, page_content='for eliminating, preventing,'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 10}, page_content='or controlling workplace hazards.'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 10}, page_content='•  C ontrols are selected according to a hierarchy that uses engineering solutions first, followed'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 10}, page_content='first, followed by'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 10}, page_content='safe work practices, administrative controls, and finally personal protective equipment (PPE).'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 10}, page_content='•  A plan is de veloped to ensure that controls are implemented, interim protection is provided,'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 10}, page_content='progress is tracked, and the effectiveness of controls is verified.\nEDUCATION &'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 10}, page_content='TRAINING•  All workers are trained to understand how the program works and how to carry out the'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 10}, page_content='responsibilities assigned to them under the program.'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 10}, page_content='•  Emplo yers, managers, and supervisors receive training on safety concepts and their'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 10}, page_content='responsibility for protecting workers’ rights and responding to workers’ reports and concerns.'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 10}, page_content='•  All w orkers are trained to recognize workplace hazards and to understand the control measures'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 10}, page_content='that have been implemented.\nPROGRAM \nEVALUATION &'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 10}, page_content='EVALUATION & \nIMPROVEMENT•  C ontrol measures are periodically evaluated for effectiveness.'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 10}, page_content='•  Pr ocesses are established to monitor program performance, verify program implementation,'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 10}, page_content='and identify program shortcomings and opportunities for improvement.'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 10}, page_content='•  Nec essary actions are taken to improve the program and overall safety and health performance.'),
# ...
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 30}, page_content='intended. After that, employers should \nperiodically, and at least annually, step back'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 30}, page_content='and assess what is working and what is not, \nand whether the program is on track to'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 30}, page_content='achieve its goals. Whenever these assessments \nidentify opportunities to improve the program,'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 30}, page_content='employers, managers, and supervisors—in \ncoordination with workers—should make'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 30}, page_content='adjustments and monitor how well the program performs as a result. Sharing the results of'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 30}, page_content='monitoring and evaluation within the workplace, \nand celebrating successes, will help drive'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 30}, page_content='further improvement.\nPROGRAM EVALUATION  and improvement \nincludes:'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 30}, page_content='includes:\n• Establishing, reporting, and tracking goals \nand targets that indicate whether the'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 30}, page_content='program is making progress. • Evaluating the program initially, and'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 30}, page_content='periodically thereafter, to identify shortcomings \nand opportunities for improvement.'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 30}, page_content='• Providing ways for workers to participate in \nprogram evaluation and improvement.'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 30}, page_content='Action item 1: Monitor performance and progress'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 30}, page_content='The first step in monitoring is to define indicators that will help track performance and progress.'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 30}, page_content='and progress. Next,'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 30}, page_content='employers, managers, supervisors, and workers need to establish and follow procedures to collect,'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 30}, page_content='analyze, and review performance data.'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 30}, page_content='Both lagging  and leading  indicators should be used. Lagging indicators generally track worker'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 30}, page_content='track worker exposures'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 30}, page_content='and injuries that have already occurred. Leading indicators track how well various aspects of the'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 30}, page_content='aspects of the program'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 30}, page_content='have been implemented and reflect steps taken to prevent injuries or illnesses before they occur.'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 30}, page_content='How to accomplish it\n• Develop and track indicators of progress'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 30}, page_content='toward established safety and health goals.\n —Track lagging indicators , such as:'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 30}, page_content='\x8aNumber and severity of injuries and \nillnesses \x8aResults of worker exposure'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 30}, page_content='monitoring that show that exposures \nare hazardous\n \x8aWorkers’ compensation data,'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 30}, page_content='including claim counts, rates, and cost\n27 osha.gov/safetymanagement'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 30}, page_content='RECOMMENDED PRACTICES FOR SAFETY AND HEALTH PROGRAMS'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 31}, page_content='—Track leading indicators , such as: \n \x8aLevel of worker participation in \nprogram activities'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 31}, page_content='program activities\n \x8aNumber of employee safety \nsuggestions\n \x8aNumber of hazards, near misses, and'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 31}, page_content='first aid cases reported \n \x8aAmount of time taken to respond to \nreports\n \x8aNumber and frequency of'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 31}, page_content='management walkthroughs \n \x8aNumber and severity of hazards \nidentified during inspections'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 31}, page_content='\x8aNumber of workers who have \ncompleted required safety and health'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 31}, page_content='training \x8aTimely completion of corrective \nactions after a workplace hazard is'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 31}, page_content='identified or an incident occurs\n \x8aTimely completion of planned \npreventive maintenance activities'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 31}, page_content='\x8aWorker opinions about program \neffectiveness obtained from a safety'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 31}, page_content='climate or safety opinion survey \n• Analyze performance indicators and evaluate'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 31}, page_content='progress over time.\n• Share results with workers and invite \ntheir input on how to further improve'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 31}, page_content='performance.\n• When opportunities arise, share your \nexperience and compare your results to'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 31}, page_content='similar facilities within your organization, \nwith other employers you know, or through'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 31}, page_content='business or trade associations.'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 31}, page_content='Note:  Indicators can be either quantitative or qualitative. Whenever possible, select indicators'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 31}, page_content='select indicators that are measurable (quantitative) and that will help'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 31}, page_content='you determine whether you have achieved your program goals. The number of reported hazards and near'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 31}, page_content='hazards and near misses would be a quantitative indicator.'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 31}, page_content='A single worker expressing a favorable opinion about program participation would be a qualitative'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 31}, page_content='be a qualitative indicator.'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 31}, page_content='Action item 2: Verify that the program is implemented and is operating'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 31}, page_content='Initially and at least annually, employers need to evaluate the program to ensure that it is'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 31}, page_content='ensure that it is operating'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 31}, page_content='as intended, is effective in controlling identified hazards, and is making progress toward'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 31}, page_content='progress toward established'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 31}, page_content='safety and health goals and objectives. The scope and frequency of program evaluations will vary'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 31}, page_content='depending on changes in OSHA standards; the scope, complexity, and maturity of the program; and'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 31}, page_content='the types of hazards it must control.\nHow to accomplish it'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 31}, page_content='• Verify that the core elements of the program \nhave been fully implemented.'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 31}, page_content='• Involve workers in all aspects of program \nevaluation, including reviewing information'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 31}, page_content='(such as incident reports and exposure \nmonitoring results); establishing and tracking'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 31}, page_content='performance indicators; and identifying \nopportunities to improve the program.'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 31}, page_content='• Verify that the following key processes are in'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 31}, page_content='place and operating as intended: —Reporting injuries, illnesses, incidents, \nhazards, and concerns'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 31}, page_content='—Conducting workplace inspections and \nincident investigations'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 31}, page_content='—Tracking progress in controlling identified \nhazards and ensuring that hazard control'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 31}, page_content='measures remain effective\n —Collecting and reporting any data needed'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 31}, page_content='to monitor progress and performance\nPROGRAM EVALUATION AND IMPROVEMENT\n28'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 31}, page_content='28\nRECOMMENDED PRACTICES FOR SAFETY AND HEALTH PROGRAMS osha.gov/safetymanagement'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 32}, page_content='• Review the results of any compliance audits'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 32}, page_content='to confirm that any program shortcomings are being identified. Verify that actions are'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 32}, page_content='being taken that will prevent recurrence.'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 32}, page_content='Action item 3: Correct program shortcomings and identify opportunities to \nimprove'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 32}, page_content='Whenever a problem is identified in any part of the safety and health program, employers—in'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 32}, page_content='coordination with supervisors, managers, and workers—should take prompt action to correct the'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 32}, page_content='problem and prevent its recurrence. \nHow to accomplish it'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 32}, page_content='• If you discover program shortcomings, take \nactions needed to correct them.'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 32}, page_content='• Proactively seek input from managers, \nworkers, supervisors, and other stakeholders'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 32}, page_content='on how you can improve the program. \n• Determine whether changes in equipment,'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 32}, page_content='facilities, materials, key personnel, or work practices trigger any need for changes in the'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 32}, page_content='program. \n• Determine whether your performance \nindicators and goals are still relevant and,'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 32}, page_content='if not, how you could change them to more \neffectively drive improvements in workplace'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 32}, page_content='safety and health.'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 32}, page_content='Note: The scope and frequency of program evaluations will depend on the scope, complexity, and'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 32}, page_content='complexity, and maturity of the program and on the types of'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 32}, page_content='hazards it must control. Program evaluations should be conducted periodically (and at least'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 32}, page_content='(and at least annually) but might also be triggered by a change in'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 32}, page_content='process or equipment, or an incident such as a serious injury, significant property damage, or an'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 32}, page_content='damage, or an increase in safety-related complaints.'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 32}, page_content='PROGRAM EVALUATION AND IMPROVEMENT\n29 osha.gov/safetymanagement'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 32}, page_content='RECOMMENDED PRACTICES FOR SAFETY AND HEALTH PROGRAMS'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 33}, page_content='COMMUNICATION AND \nCOORDINATION FOR \nHOST EMPLOYERS, \nCONTRACTORS, AND \nSTAFFING AGENCIES'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 33}, page_content='STAFFING AGENCIES\nIN TODAY’S ECONOMY , an increasing number'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 33}, page_content='of workers are assigned by staffing agencies \nto work at specific “host” worksites under the'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 33}, page_content='direction and control of the host employer. \nExamples include seasonal workers, such as'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 33}, page_content='delivery drivers and warehouse workers, who \nhelp fill a temporary staffing need, as well as'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 33}, page_content='office and production workers who may be \nplaced in both short- and long-term assignments.'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 33}, page_content='In these situations, it is important for the staffing'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 33}, page_content='agency and the host employer  to communicate \nand coordinate to provide and maintain a safe'),
#  Document(metadata={'source': './documents\\OSHA3885.pdf', 'page': 33}, page_content='work environment for their workers.In other situations, some workers are employed'),
#  ...]

# %%
db = Chroma.from_documents(docs, embeddings, persist_directory="my_embeddings")

# %%
# !pip install -qU "langchain-chroma>=0.1.2"
